# %%
import pandas as pd

# Read the Excel file (first sheet is loaded by default)
df = pd.read_excel("../DataScraper/UPI_data/Ecosystem-Statistics-UPI-Upi-apps-2025-Oct.xlsx")

# Save to CSV
df.to_csv("../DataScraper/UPI_data/Ecosystem-Statistics-UPI-Upi-apps-2025-Oct-csv.csv", index=False)

# %%
import pandas as pd

# Read the Excel file (first sheet is loaded by default)
df = pd.read_excel("../DataScraper\Merchant Category Classification\Ecosystem-Statistics-UPI-Merchant-category-classification-2025-Oct.xlsx")

# Save to CSV
df.to_csv("../DataScraper\Merchant Category Classification\Ecosystem-Statistics-UPI-Merchant-category-classification-2025-Oct.csv", index=False)
